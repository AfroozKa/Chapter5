# %%
import yfinance as yf

tesla = yf.Ticker("TSLA")
tesla_data = tesla.history(period="max")

print(tesla_data.head())
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667  281494500
# 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667  257806500
# 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000  123282000
# 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000   77097000
# 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000  103003500
#
#                            Dividends  Stock Splits
# Date
# 2010-06-29 00:00:00-04:00        0.0           0.0
# 2010-06-30 00:00:00-04:00        0.0           0.0
# 2010-07-01 00:00:00-04:00        0.0           0.0
# 2010-07-02 00:00:00-04:00        0.0           0.0
# 2010-07-06 00:00:00-04:00        0.0           0.0

# %%
import requests
from bs4 import BeautifulSoup

# URL for Tesla revenue data (example: Macrotrends)
url = "https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue"

# Send HTTP request
headers = {"User-Agent": "Mozilla/5.0"}  # Mimic a real browser
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

# Extract the revenue table
tables = soup.find_all("table")
for table in tables:
    if "Revenue" in table.text:
        tesla_revenue = pd.read_html(str(table))[0]
        break

# Display Tesla revenue data
print(tesla_revenue.head())
# Out:
#    Tesla Annual Revenue (Millions of US $)  \
# 0                                     2024
# 1                                     2023
# 2                                     2022
# 3                                     2021
# 4                                     2020
#
#   Tesla Annual Revenue (Millions of US $).1
# 0                                   $97,690
# 1                                   $96,773
# 2                                   $81,462
# 3                                   $53,823
# 4                                   $31,536
# C:\Users\afroo\AppData\Local\Temp\ipykernel_21976\669296176.py:16: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tesla_revenue = pd.read_html(str(table))[0]

# %%
gamestop = yf.Ticker("GME")
gamestop_data = gamestop.history(period="max")
print(gamestop_data.head())
# Out:
#                                Open      High       Low     Close    Volume  \
# Date
# 2002-02-13 00:00:00-05:00  1.620129  1.693350  1.603296  1.691667  76216000
# 2002-02-14 00:00:00-05:00  1.712707  1.716074  1.670626  1.683250  11021600
# 2002-02-15 00:00:00-05:00  1.683250  1.687458  1.658001  1.674834   8389600
# 2002-02-19 00:00:00-05:00  1.666418  1.666418  1.578047  1.607504   7410400
# 2002-02-20 00:00:00-05:00  1.615921  1.662210  1.603296  1.662210   6892800
#
#                            Dividends  Stock Splits
# Date
# 2002-02-13 00:00:00-05:00        0.0           0.0
# 2002-02-14 00:00:00-05:00        0.0           0.0
# 2002-02-15 00:00:00-05:00        0.0           0.0
# 2002-02-19 00:00:00-05:00        0.0           0.0
# 2002-02-20 00:00:00-05:00        0.0           0.0

# %%
# URL for GameStop revenue data (example: Macrotrends)
url = "https://www.macrotrends.net/stocks/charts/GME/gamestop/revenue"

# Send HTTP request
headers = {"User-Agent": "Mozilla/5.0"}  # Mimic a real browser
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

# Extract the revenue table
tables = soup.find_all("table")
for table in tables:
    if "Revenue" in table.text:
        gamestop_revenue = pd.read_html(str(table))[0]
        break

# Display GameStop revenue data
print(gamestop_revenue.head())
# Out:
#    GameStop Annual Revenue (Millions of US $)  \
# 0                                        2024
# 1                                        2023
# 2                                        2022
# 3                                        2021
# 4                                        2020
#
#   GameStop Annual Revenue (Millions of US $).1
# 0                                       $5,273
# 1                                       $5,927
# 2                                       $6,011
# 3                                       $5,090
# 4                                       $6,466
# C:\Users\afroo\AppData\Local\Temp\ipykernel_21976\697554037.py:13: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   gamestop_revenue = pd.read_html(str(table))[0]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(tesla_data.index, tesla_data["Close"], label="Stock Price")
plt.xlabel("Year")
plt.ylabel("Stock Price (USD)")
plt.title("Tesla Stock Price Over Time")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(gamestop_data.index, gamestop_data["Close"], label="Stock Price")
plt.xlabel("Year")
plt.ylabel("Stock Price (USD)")
plt.title("Gamestop Stock Price Over Time")
plt.legend()
plt.show()
